# %%
# imports 
import scipy
import scipy.constants as constants
import math
import numpy as np

print("Mein erstes GitHub-Jupyter")
# Out:
# Mein erstes GitHub-Jupyter

# %%
# constants 
h = constants.Planck # Js
kB = constants.Boltzmann # J/K
I = 4.67e-48  # kgm^2
pi = constants.pi 
R = constants.gas_constant # J/(molK)

print("h =",h,"Js")
print("kB =",kB,"J/K")
print("Moment of Inertia =",I,"kgm^2")
print("pi =",pi,"[-]")
print("R =",R,"J/(molK)")
# Out:
# h = 6.62607015e-34 Js
# kB = 1.380649e-23 J/K
# Moment of Inertia = 4.67e-48 kgm^2
# pi = 3.141592653589793 [-]
# R = 8.31446261815324 J/(molK)
